# %% [markdown]
# <a href="https://colab.research.google.com/github/QasimHassan78/AI/blob/master/Monotone.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
import scipy.io.wavfile as write

# %%
import matplotlib.pyplot as plt

# %%
output_file="qasim.wav"
duration = 4
frequency_sampling = 44100
frequency_tone = 784
min_val=-4 * np.pi
max_val=4 * np.pi

# %%
t = np.linspace(min_val,max_val,duration*frequency_sampling)
audio_signal =np.sin(2 * np.pi * frequency_tone * t)

# %%
write(output_file,frequency_sampling)

# %%
audio_signal = audio_signal[:100]
time_axis = 1000*np.arange(0,len(audio_signal),1)/float(frequency_sampling)

# %%
plt.plot(time_axis,audio_signal,color='blue')
plt.xlabel("time in milliseconds")
plt.ylabel("Amplitude")
plt.title("Generated Audio signal")
plt.show()
